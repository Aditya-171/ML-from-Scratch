# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
age=df.iloc[:,2]
salary=df.iloc[:,3]

# %%
age
# Out:
# 0      19
# 1      35
# 2      26
# 3      27
# 4      19
#        ..
# 395    46
# 396    51
# 397    50
# 398    36
# 399    49
# Name: Age, Length: 400, dtype: int64

# %%
salary
# Out:
# 0      19000
# 1      20000
# 2      43000
# 3      57000
# 4      76000
#        ...
# 395    41000
# 396    23000
# 397    20000
# 398    33000
# 399    36000
# Name: EstimatedSalary, Length: 400, dtype: int64

# %%
# Finding out the min and max value of age
print(age.min())
print(age.max())
# Out:
# 18
# 60

# %% [markdown]
# ### Performing MinMax Scaling

# %%
# performin minmax Scaling on age
for i in range(0,400):
    x= (age[i]-18)/(60-18)
    age[i]=x
    print(x)
# Out:
# 0.023809523809523808
# 0.40476190476190477
# 0.19047619047619047
# 0.21428571428571427
# 0.023809523809523808
# 0.21428571428571427
# 0.21428571428571427
# 0.3333333333333333
# 0.16666666666666666
# 0.40476190476190477
# 0.19047619047619047
# 0.19047619047619047
# 0.047619047619047616
# 0.3333333333333333
# 0.0
# 0.2619047619047619
# 0.6904761904761905
# 0.6428571428571429
# 0.6666666666666666
# 0.7142857142857143
# 0.6428571428571429
# 0.6904761904761905
# 0.7142857142857143
# 0.6428571428571429
# 0.6666666666666666
# 0.6904761904761905
# 0.7380952380952381
# 0.6904761904761905
# 0.2619047619047619
# 0.30952380952380953
# 0.30952380952380953
# 0.21428571428571427
# 0.07142857142857142
# 0.23809523809523808
# 0.21428571428571427
# 0.40476190476190477
# 0.35714285714285715
# 0.2857142857142857
# 0.19047619047619047
# 0.21428571428571427
# 0.21428571428571427
# 0.35714285714285715
# 0.40476190476190477
# 0.2857142857142857
# 0.23809523809523808
# 0.11904761904761904
# ...

# %%
# Finding out the min and max value of salary
min_S=salary.min()
max_S=salary.max()
print(min_S)
print(max_S)
# Out:
# 15000
# 150000

# %%
# performin minmax Scaling on Salary
for i in range(0,400):
    x= (salary[i]-min_S)/(max_S-min_S)
    age[i]=x
    print(x)
# Out:
# 0.02962962962962963
# 0.037037037037037035
# 0.2074074074074074
# 0.3111111111111111
# 0.45185185185185184
# 0.31851851851851853
# 0.5111111111111111
# 1.0
# 0.13333333333333333
# 0.37037037037037035
# 0.48148148148148145
# 0.2740740740740741
# 0.5259259259259259
# 0.022222222222222223
# 0.4962962962962963
# 0.48148148148148145
# 0.07407407407407407
# 0.08148148148148149
# 0.0962962962962963
# 0.1037037037037037
# 0.05185185185185185
# 0.2518518518518518
# 0.1925925925925926
# 0.05185185185185185
# 0.05925925925925926
# 0.037037037037037035
# 0.0962962962962963
# 0.1111111111111111
# 0.2074074074074074
# 0.022222222222222223
# 0.43703703703703706
# 0.9037037037037037
# 0.007407407407407408
# 0.21481481481481482
# 0.5555555555555556
# 0.08888888888888889
# 0.0962962962962963
# 0.2518518518518518
# 0.4222222222222222
# 0.11851851851851852
# 0.014814814814814815
# 0.26666666666666666
# 0.6888888888888889
# 0.0
# 0.5111111111111111
# 0.037037037037037035
# 0.4740740740740741
# ...
